# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(
    r"D:\Retail Pulse Project\data\cleaned_retail.csv"
)

df["InvoiceDate"] = pd.to_datetime(
    df["InvoiceDate"]
)
# Out:
# C:\Users\PAVILION\AppData\Local\Temp\ipykernel_12460\3782407487.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
monthly_sales = (
    df.groupby(
        df["InvoiceDate"]
        .dt.to_period("M")
    )["Revenue"]
    .sum()
)

monthly_sales.plot(
    figsize=(12,5)
)

plt.title(
    "Monthly Revenue Trend"
)

plt.show()

# %%
top_countries = (
    df.groupby("Country")
    ["Revenue"]
    .sum()
    .sort_values(
        ascending=False
    )
    .head(10)
)

top_countries.plot(
    kind="bar",
    figsize=(10,5)
)

plt.show()

# %%
top_products = (
    df.groupby("Description")
    ["Revenue"]
    .sum()
    .sort_values(
        ascending=False
    )
    .head(10)
)

top_products.plot(
    kind="bar"
)

plt.show()

# %%
sns.histplot(
    df["Revenue"],
    bins=50
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df[["Quantity","Price","Revenue"]].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="Blues"
)

plt.title(
    "Correlation Heatmap"
)

plt.show()
